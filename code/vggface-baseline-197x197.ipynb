# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['train', 'test', 'train_relationships.csv', 'sample_submission.csv']

# %%
from collections import defaultdict
from glob import glob
from random import choice, sample
from keras.preprocessing import image
import cv2
import numpy as np
import pandas as pd
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.layers import Input, Dense, GlobalMaxPool2D, GlobalAvgPool2D, Concatenate, Multiply, Dropout, Subtract
from keras.models import Model
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
# !pip install git+https://github.com/rcmalli/keras-vggface.git
# Out:
# Collecting git+https://github.com/rcmalli/keras-vggface.git
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-ow8pt6zj
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-ow8pt6zj
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (1.3.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (2.9.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (5.4.1)
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (1.12.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras-vggface==0.5) (5.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras-vggface==0.5) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras-vggface==0.5) (1.0.8)
# Building wheels for collected packages: keras-vggface
# done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-orksd2ah/wheels/36/07/46/06c25ce8e9cd396dabe151ea1d8a2bc28dafcb11321c1f3a6d
# Successfully built keras-vggface
# Installing collected packages: keras-vggface
# Successfully installed keras-vggface-0.5

# %%
from keras_vggface.utils import preprocess_input
from keras_vggface.vggface import VGGFace

# %%
train_file_path = "../input/train_relationships.csv"
train_folders_path = "../input/train/"
val_famillies = "F09"

all_images = glob(train_folders_path + "*/*/*.jpg")

train_images = [x for x in all_images if val_famillies not in x]
val_images = [x for x in all_images if val_famillies in x]

train_person_to_images_map = defaultdict(list)

ppl = [x.split("/")[-3] + "/" + x.split("/")[-2] for x in all_images]

for x in train_images:
    train_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

val_person_to_images_map = defaultdict(list)

for x in val_images:
    val_person_to_images_map[x.split("/")[-3] + "/" + x.split("/")[-2]].append(x)

# %%
relationships = pd.read_csv(train_file_path)
relationships = list(zip(relationships.p1.values, relationships.p2.values))
relationships = [x for x in relationships if x[0] in ppl and x[1] in ppl]

train = [x for x in relationships if val_famillies not in x[0]]
val = [x for x in relationships if val_famillies in x[0]]

# %%
def read_img(path):
    img = image.load_img(path, target_size=(197, 197))
    img = np.array(img).astype(np.float)
    return preprocess_input(img, version=2)

def gen(list_tuples, person_to_images_map, batch_size=16):
    ppl = list(person_to_images_map.keys())
    while True:
        batch_tuples = sample(list_tuples, batch_size // 2)
        labels = [1] * len(batch_tuples)
        while len(batch_tuples) < batch_size:
            p1 = choice(ppl)
            p2 = choice(ppl)

            if p1 != p2 and (p1, p2) not in list_tuples and (p2, p1) not in list_tuples:
                batch_tuples.append((p1, p2))
                labels.append(0)

        for x in batch_tuples:
            if not len(person_to_images_map[x[0]]):
                print(x[0])

        X1 = [choice(person_to_images_map[x[0]]) for x in batch_tuples]
        X1 = np.array([read_img(x) for x in X1])

        X2 = [choice(person_to_images_map[x[1]]) for x in batch_tuples]
        X2 = np.array([read_img(x) for x in X2])

        yield [X1, X2], labels


def baseline_model():
    input_1 = Input(shape=(197, 197, 3))
    input_2 = Input(shape=(197, 197, 3))

    base_model = VGGFace(model='resnet50', include_top=False)

    for x in base_model.layers[:-3]:
        x.trainable = True

    x1 = base_model(input_1)
    x2 = base_model(input_2)

#     x1_ = Reshape(target_shape=(7*7, 2048))(x1)
#     x2_ = Reshape(target_shape=(7*7, 2048))(x2)
#     #
#     x_dot = Dot(axes=[2, 2], normalize=True)([x1_, x2_])
#     x_dot = Flatten()(x_dot)

    x1 = Concatenate(axis=-1)([GlobalMaxPool2D()(x1), GlobalAvgPool2D()(x1)])
    x2 = Concatenate(axis=-1)([GlobalMaxPool2D()(x2), GlobalAvgPool2D()(x2)])

    x3 = Subtract()([x1, x2])
    x3 = Multiply()([x3, x3])

    x1_ = Multiply()([x1, x1])
    x2_ = Multiply()([x2, x2])
    x4 = Subtract()([x1_, x2_])
    x = Concatenate(axis=-1)([x4, x3])

    x = Dense(100, activation="relu")(x)
    x = Dropout(0.01)(x)
    out = Dense(1, activation="sigmoid")(x)

    model = Model([input_1, input_2], out)

    model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=Adam(0.00001))

    model.summary()

    return model

# %%
file_path = "vgg_face.h5"

checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

reduce_on_plateau = ReduceLROnPlateau(monitor="val_acc", mode="max", factor=0.1, patience=20, verbose=1)

callbacks_list = [checkpoint, reduce_on_plateau]

model = baseline_model()
#model.load_weights(file_path)
model.fit_generator(gen(train, train_person_to_images_map, batch_size=16), use_multiprocessing=True,
                    validation_data=gen(val, val_person_to_images_map, batch_size=16), epochs=100, verbose=2,
                    workers=4, callbacks=callbacks_list, steps_per_epoch=200, validation_steps=100)
# Out:
# Downloading data from https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_resnet50.h5
# 94699520/94694792 [==============================] - 1s 0us/step
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 197, 197, 3)  0
# __________________________________________________________________________________________________
# vggface_resnet50 (Model)        multiple             23561152    input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           vggface_resnet50[1][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 2048)         0           vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           vggface_resnet50[2][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4096)         0           global_max_pooling2d_1[0][0]
#                                                                  global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 4096)         0           global_max_pooling2d_2[0][0]
#                                                                  global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4096)         0           concatenate_2[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 4096)         0           concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 4096)         0           multiply_2[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096)         0           subtract_1[0][0]
#                                                                  subtract_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8192)         0           subtract_2[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          819300      concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            101         dropout_1[0][0]
# ==================================================================================================
# Total params: 24,380,553
# Trainable params: 24,327,433
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Epoch 1/100
# /opt/conda/lib/python3.6/site-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
#  - 80s - loss: 3.2214 - acc: 0.5928 - val_loss: 3.3229 - val_acc: 0.6088
#
# Epoch 00001: val_acc improved from -inf to 0.60875, saving model to vgg_face.h5
# Epoch 2/100
#  - 57s - loss: 1.6560 - acc: 0.6128 - val_loss: 1.7492 - val_acc: 0.6012
#
# Epoch 00002: val_acc did not improve from 0.60875
# Epoch 3/100
#  - 58s - loss: 0.9348 - acc: 0.6506 - val_loss: 1.1606 - val_acc: 0.6194
#
# Epoch 00003: val_acc improved from 0.60875 to 0.61938, saving model to vgg_face.h5
# Epoch 4/100
#  - 57s - loss: 0.7235 - acc: 0.6687 - val_loss: 0.8866 - val_acc: 0.6344
#
# Epoch 00004: val_acc improved from 0.61938 to 0.63438, saving model to vgg_face.h5
# Epoch 5/100
#  - 56s - loss: 0.6183 - acc: 0.6966 - val_loss: 0.7497 - val_acc: 0.6431
#
# Epoch 00005: val_acc improved from 0.63438 to 0.64312, saving model to vgg_face.h5
# Epoch 6/100
#  - 56s - loss: 0.5734 - acc: 0.7128 - val_loss: 0.6631 - val_acc: 0.6931
#
# Epoch 00006: val_acc improved from 0.64312 to 0.69312, saving model to vgg_face.h5
# Epoch 7/100
#  - 57s - loss: 0.5456 - acc: 0.7181 - val_loss: 0.6325 - val_acc: 0.6975
#
# Epoch 00007: val_acc improved from 0.69312 to 0.69750, saving model to vgg_face.h5
# Epoch 8/100
#  - 56s - loss: 0.5210 - acc: 0.7347 - val_loss: 0.5932 - val_acc: 0.7150
#
# Epoch 00008: val_acc improved from 0.69750 to 0.71500, saving model to vgg_face.h5
# Epoch 9/100
#  - 57s - loss: 0.5120 - acc: 0.7431 - val_loss: 0.5447 - val_acc: 0.7212
#
# Epoch 00009: val_acc improved from 0.71500 to 0.72125, saving model to vgg_face.h5
# Epoch 10/100
#  - 56s - loss: 0.4921 - acc: 0.7600 - val_loss: 0.5559 - val_acc: 0.7200
#
# Epoch 00010: val_acc did not improve from 0.72125
# Epoch 11/100
#  - 56s - loss: 0.4738 - acc: 0.7634 - val_loss: 0.5104 - val_acc: 0.7494
#
# Epoch 00011: val_acc improved from 0.72125 to 0.74938, saving model to vgg_face.h5
# Epoch 12/100
#  - 56s - loss: 0.4584 - acc: 0.7762 - val_loss: 0.5335 - val_acc: 0.7406
#
# Epoch 00012: val_acc did not improve from 0.74938
# Epoch 13/100
#  - 56s - loss: 0.4464 - acc: 0.7847 - val_loss: 0.5040 - val_acc: 0.7569
#
# Epoch 00013: val_acc improved from 0.74938 to 0.75687, saving model to vgg_face.h5
# Epoch 14/100
#  - 57s - loss: 0.4593 - acc: 0.7784 - val_loss: 0.4768 - val_acc: 0.7581
#
# Epoch 00014: val_acc improved from 0.75687 to 0.75813, saving model to vgg_face.h5
# Epoch 15/100
#  - 56s - loss: 0.4292 - acc: 0.8016 - val_loss: 0.5234 - val_acc: 0.7488
#
# Epoch 00015: val_acc did not improve from 0.75813
# Epoch 16/100
#  - 57s - loss: 0.4412 - acc: 0.7934 - val_loss: 0.4580 - val_acc: 0.7731
#
# Epoch 00016: val_acc improved from 0.75813 to 0.77312, saving model to vgg_face.h5
# Epoch 17/100
#  - 56s - loss: 0.4205 - acc: 0.8050 - val_loss: 0.4689 - val_acc: 0.7712
#
# Epoch 00017: val_acc did not improve from 0.77312
# Epoch 18/100
#  - 57s - loss: 0.3993 - acc: 0.8175 - val_loss: 0.4830 - val_acc: 0.7744
#
# Epoch 00018: val_acc improved from 0.77312 to 0.77438, saving model to vgg_face.h5
# Epoch 19/100
#  - 57s - loss: 0.4043 - acc: 0.8181 - val_loss: 0.4908 - val_acc: 0.7738
#
# Epoch 00019: val_acc did not improve from 0.77438
# Epoch 20/100
#  - 57s - loss: 0.4067 - acc: 0.8119 - val_loss: 0.4913 - val_acc: 0.7669
#
# Epoch 00020: val_acc did not improve from 0.77438
# Epoch 21/100
#  - 57s - loss: 0.3919 - acc: 0.8269 - val_loss: 0.4907 - val_acc: 0.7794
#
# Epoch 00021: val_acc improved from 0.77438 to 0.77938, saving model to vgg_face.h5
# Epoch 22/100
#  - 57s - loss: 0.3640 - acc: 0.8347 - val_loss: 0.5031 - val_acc: 0.7712
#
# Epoch 00022: val_acc did not improve from 0.77938
# Epoch 23/100
#  - 57s - loss: 0.3844 - acc: 0.8266 - val_loss: 0.4802 - val_acc: 0.7644
#
# Epoch 00023: val_acc did not improve from 0.77938
# Epoch 24/100
#  - 57s - loss: 0.3596 - acc: 0.8291 - val_loss: 0.4531 - val_acc: 0.7837
#
# Epoch 00024: val_acc improved from 0.77938 to 0.78375, saving model to vgg_face.h5
# Epoch 25/100
#  - 56s - loss: 0.3727 - acc: 0.8466 - val_loss: 0.4863 - val_acc: 0.7681
#
# Epoch 00025: val_acc did not improve from 0.78375
# Epoch 26/100
#  - 57s - loss: 0.3592 - acc: 0.8431 - val_loss: 0.5123 - val_acc: 0.7606
#
# Epoch 00026: val_acc did not improve from 0.78375
# Epoch 27/100
#  - 57s - loss: 0.3550 - acc: 0.8456 - val_loss: 0.5038 - val_acc: 0.7812
#
# Epoch 00027: val_acc did not improve from 0.78375
# Epoch 28/100
#  - 57s - loss: 0.3669 - acc: 0.8347 - val_loss: 0.4838 - val_acc: 0.7750
#
# Epoch 00028: val_acc did not improve from 0.78375
# Epoch 29/100
#  - 57s - loss: 0.3503 - acc: 0.8500 - val_loss: 0.4757 - val_acc: 0.7756
#
# Epoch 00029: val_acc did not improve from 0.78375
# Epoch 30/100
#  - 57s - loss: 0.3515 - acc: 0.8444 - val_loss: 0.4764 - val_acc: 0.7806
#
# Epoch 00030: val_acc did not improve from 0.78375
# Epoch 31/100
#  - 57s - loss: 0.3363 - acc: 0.8491 - val_loss: 0.4926 - val_acc: 0.7619
#
# Epoch 00031: val_acc did not improve from 0.78375
# Epoch 32/100
#  - 57s - loss: 0.3442 - acc: 0.8447 - val_loss: 0.4813 - val_acc: 0.7756
#
# Epoch 00032: val_acc did not improve from 0.78375
# Epoch 33/100
#  - 57s - loss: 0.3453 - acc: 0.8516 - val_loss: 0.4698 - val_acc: 0.7775
#
# Epoch 00033: val_acc did not improve from 0.78375
# Epoch 34/100
#  - 58s - loss: 0.3328 - acc: 0.8591 - val_loss: 0.5172 - val_acc: 0.7788
#
# Epoch 00034: val_acc did not improve from 0.78375
# Epoch 35/100
#  - 57s - loss: 0.3362 - acc: 0.8541 - val_loss: 0.4902 - val_acc: 0.7913
#
# Epoch 00035: val_acc improved from 0.78375 to 0.79125, saving model to vgg_face.h5
# Epoch 36/100
#  - 56s - loss: 0.3256 - acc: 0.8587 - val_loss: 0.4956 - val_acc: 0.7788
#
# Epoch 00036: val_acc did not improve from 0.79125
# Epoch 37/100
#  - 57s - loss: 0.3061 - acc: 0.8728 - val_loss: 0.4943 - val_acc: 0.7781
#
# Epoch 00037: val_acc did not improve from 0.79125
# Epoch 38/100
#  - 57s - loss: 0.3303 - acc: 0.8616 - val_loss: 0.4802 - val_acc: 0.7700
#
# Epoch 00038: val_acc did not improve from 0.79125
# Epoch 39/100
#  - 57s - loss: 0.3141 - acc: 0.8628 - val_loss: 0.4992 - val_acc: 0.7688
#
# Epoch 00039: val_acc did not improve from 0.79125
# Epoch 40/100
#  - 56s - loss: 0.3082 - acc: 0.8619 - val_loss: 0.4730 - val_acc: 0.7769
#
# Epoch 00040: val_acc did not improve from 0.79125
# Epoch 41/100
#  - 57s - loss: 0.3027 - acc: 0.8700 - val_loss: 0.5315 - val_acc: 0.7638
#
# Epoch 00041: val_acc did not improve from 0.79125
# Epoch 42/100
#  - 57s - loss: 0.2975 - acc: 0.8750 - val_loss: 0.4813 - val_acc: 0.7712
#
# Epoch 00042: val_acc did not improve from 0.79125
# Epoch 43/100
#  - 57s - loss: 0.2855 - acc: 0.8816 - val_loss: 0.4726 - val_acc: 0.7844
#
# Epoch 00043: val_acc did not improve from 0.79125
# Epoch 44/100
#  - 57s - loss: 0.2903 - acc: 0.8756 - val_loss: 0.4817 - val_acc: 0.7775
#
# Epoch 00044: val_acc did not improve from 0.79125
# Epoch 45/100
#  - 57s - loss: 0.2972 - acc: 0.8681 - val_loss: 0.4635 - val_acc: 0.7812
#
# Epoch 00045: val_acc did not improve from 0.79125
# Epoch 46/100
#  - 57s - loss: 0.2892 - acc: 0.8806 - val_loss: 0.4468 - val_acc: 0.7975
#
# Epoch 00046: val_acc improved from 0.79125 to 0.79750, saving model to vgg_face.h5
# Epoch 47/100
#  - 56s - loss: 0.2704 - acc: 0.8916 - val_loss: 0.5037 - val_acc: 0.7675
#
# Epoch 00047: val_acc did not improve from 0.79750
# Epoch 48/100
#  - 57s - loss: 0.3003 - acc: 0.8728 - val_loss: 0.4782 - val_acc: 0.7869
#
# Epoch 00048: val_acc did not improve from 0.79750
# Epoch 49/100
#  - 57s - loss: 0.2794 - acc: 0.8856 - val_loss: 0.4758 - val_acc: 0.7925
#
# Epoch 00049: val_acc did not improve from 0.79750
# Epoch 50/100
#  - 57s - loss: 0.2733 - acc: 0.8869 - val_loss: 0.4988 - val_acc: 0.7975
#
# Epoch 00050: val_acc did not improve from 0.79750
# Epoch 51/100
#  - 57s - loss: 0.2732 - acc: 0.8903 - val_loss: 0.4999 - val_acc: 0.7700
#
# Epoch 00051: val_acc did not improve from 0.79750
# Epoch 52/100
#  - 57s - loss: 0.2812 - acc: 0.8853 - val_loss: 0.5168 - val_acc: 0.7781
#
# Epoch 00052: val_acc did not improve from 0.79750
# Epoch 53/100
#  - 57s - loss: 0.2633 - acc: 0.8897 - val_loss: 0.5162 - val_acc: 0.7712
#
# Epoch 00053: val_acc did not improve from 0.79750
# Epoch 54/100
#  - 57s - loss: 0.2764 - acc: 0.8856 - val_loss: 0.5020 - val_acc: 0.7669
#
# Epoch 00054: val_acc did not improve from 0.79750
# Epoch 55/100
#  - 57s - loss: 0.2548 - acc: 0.8944 - val_loss: 0.5207 - val_acc: 0.7706
#
# Epoch 00055: val_acc did not improve from 0.79750
# Epoch 56/100
#  - 57s - loss: 0.2677 - acc: 0.8887 - val_loss: 0.5602 - val_acc: 0.7638
#
# Epoch 00056: val_acc did not improve from 0.79750
# Epoch 57/100
#  - 58s - loss: 0.2716 - acc: 0.8847 - val_loss: 0.5036 - val_acc: 0.7738
#
# Epoch 00057: val_acc did not improve from 0.79750
# Epoch 58/100
#  - 57s - loss: 0.2567 - acc: 0.8903 - val_loss: 0.5436 - val_acc: 0.7562
#
# Epoch 00058: val_acc did not improve from 0.79750
# Epoch 59/100
#  - 57s - loss: 0.2436 - acc: 0.9006 - val_loss: 0.5116 - val_acc: 0.7775
#
# Epoch 00059: val_acc did not improve from 0.79750
# Epoch 60/100
#  - 57s - loss: 0.2492 - acc: 0.8925 - val_loss: 0.5171 - val_acc: 0.7881
#
# Epoch 00060: val_acc did not improve from 0.79750
# Epoch 61/100
#  - 57s - loss: 0.2390 - acc: 0.9044 - val_loss: 0.5423 - val_acc: 0.7788
#
# Epoch 00061: val_acc did not improve from 0.79750
# Epoch 62/100
#  - 58s - loss: 0.2370 - acc: 0.9047 - val_loss: 0.5311 - val_acc: 0.7719
#
# Epoch 00062: val_acc did not improve from 0.79750
# Epoch 63/100
#  - 56s - loss: 0.2307 - acc: 0.9059 - val_loss: 0.5342 - val_acc: 0.7738
#
# Epoch 00063: val_acc did not improve from 0.79750
# Epoch 64/100
#  - 58s - loss: 0.2431 - acc: 0.9047 - val_loss: 0.5538 - val_acc: 0.7575
#
# Epoch 00064: val_acc did not improve from 0.79750
# Epoch 65/100
#  - 57s - loss: 0.2337 - acc: 0.9050 - val_loss: 0.5969 - val_acc: 0.7644
#
# Epoch 00065: val_acc did not improve from 0.79750
# Epoch 66/100
#  - 57s - loss: 0.2298 - acc: 0.9050 - val_loss: 0.5372 - val_acc: 0.7631
#
# Epoch 00066: val_acc did not improve from 0.79750
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 67/100
#  - 56s - loss: 0.2326 - acc: 0.9072 - val_loss: 0.5399 - val_acc: 0.7581
#
# Epoch 00067: val_acc did not improve from 0.79750
# Epoch 68/100
#  - 56s - loss: 0.2230 - acc: 0.9072 - val_loss: 0.5685 - val_acc: 0.7575
#
# Epoch 00068: val_acc did not improve from 0.79750
# Epoch 69/100
#  - 56s - loss: 0.2123 - acc: 0.9137 - val_loss: 0.5853 - val_acc: 0.7431
#
# Epoch 00069: val_acc did not improve from 0.79750
# Epoch 70/100
#  - 56s - loss: 0.1963 - acc: 0.9209 - val_loss: 0.5614 - val_acc: 0.7638
#
# Epoch 00070: val_acc did not improve from 0.79750
# Epoch 71/100
#  - 57s - loss: 0.2112 - acc: 0.9159 - val_loss: 0.5754 - val_acc: 0.7556
#
# Epoch 00071: val_acc did not improve from 0.79750
# Epoch 72/100
#  - 57s - loss: 0.2225 - acc: 0.9094 - val_loss: 0.5930 - val_acc: 0.7438
#
# Epoch 00072: val_acc did not improve from 0.79750
# Epoch 73/100
#  - 56s - loss: 0.2054 - acc: 0.9222 - val_loss: 0.5653 - val_acc: 0.7550
#
# Epoch 00073: val_acc did not improve from 0.79750
# Epoch 74/100
#  - 56s - loss: 0.1904 - acc: 0.9225 - val_loss: 0.5556 - val_acc: 0.7694
#
# Epoch 00074: val_acc did not improve from 0.79750
# Epoch 75/100
#  - 56s - loss: 0.1905 - acc: 0.9253 - val_loss: 0.5702 - val_acc: 0.7581
#
# Epoch 00075: val_acc did not improve from 0.79750
# Epoch 76/100
#  - 56s - loss: 0.2043 - acc: 0.9184 - val_loss: 0.6129 - val_acc: 0.7519
#
# Epoch 00076: val_acc did not improve from 0.79750
# Epoch 77/100
#  - 56s - loss: 0.1913 - acc: 0.9234 - val_loss: 0.5750 - val_acc: 0.7481
#
# Epoch 00077: val_acc did not improve from 0.79750
# Epoch 78/100
#  - 56s - loss: 0.1864 - acc: 0.9238 - val_loss: 0.6284 - val_acc: 0.7519
#
# Epoch 00078: val_acc did not improve from 0.79750
# Epoch 79/100
#  - 56s - loss: 0.1767 - acc: 0.9284 - val_loss: 0.6392 - val_acc: 0.7388
#
# Epoch 00079: val_acc did not improve from 0.79750
# Epoch 80/100
#  - 56s - loss: 0.1852 - acc: 0.9309 - val_loss: 0.6125 - val_acc: 0.7500
#
# Epoch 00080: val_acc did not improve from 0.79750
# Epoch 81/100
#  - 57s - loss: 0.1770 - acc: 0.9284 - val_loss: 0.5992 - val_acc: 0.7538
#
# Epoch 00081: val_acc did not improve from 0.79750
# Epoch 82/100
#  - 56s - loss: 0.1844 - acc: 0.9281 - val_loss: 0.6252 - val_acc: 0.7469
#
# Epoch 00082: val_acc did not improve from 0.79750
# Epoch 83/100
#  - 56s - loss: 0.1791 - acc: 0.9344 - val_loss: 0.6671 - val_acc: 0.7331
#
# Epoch 00083: val_acc did not improve from 0.79750
# Epoch 84/100
#  - 56s - loss: 0.1840 - acc: 0.9288 - val_loss: 0.6113 - val_acc: 0.7606
#
# Epoch 00084: val_acc did not improve from 0.79750
# Epoch 85/100
#  - 57s - loss: 0.1626 - acc: 0.9416 - val_loss: 0.6040 - val_acc: 0.7450
#
# Epoch 00085: val_acc did not improve from 0.79750
# Epoch 86/100
#  - 56s - loss: 0.1889 - acc: 0.9266 - val_loss: 0.5859 - val_acc: 0.7525
#
# Epoch 00086: val_acc did not improve from 0.79750
#
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 87/100
#  - 57s - loss: 0.1657 - acc: 0.9369 - val_loss: 0.5966 - val_acc: 0.7538
#
# Epoch 00087: val_acc did not improve from 0.79750
# Epoch 88/100
#  - 56s - loss: 0.1583 - acc: 0.9403 - val_loss: 0.5956 - val_acc: 0.7531
#
# Epoch 00088: val_acc did not improve from 0.79750
# Epoch 89/100
#  - 56s - loss: 0.1779 - acc: 0.9291 - val_loss: 0.6147 - val_acc: 0.7619
#
# Epoch 00089: val_acc did not improve from 0.79750
# Epoch 90/100
#  - 56s - loss: 0.1652 - acc: 0.9391 - val_loss: 0.6431 - val_acc: 0.7344
#
# Epoch 00090: val_acc did not improve from 0.79750
# Epoch 91/100
#  - 56s - loss: 0.1703 - acc: 0.9369 - val_loss: 0.5243 - val_acc: 0.7738
#
# Epoch 00091: val_acc did not improve from 0.79750
# Epoch 92/100
#  - 56s - loss: 0.1851 - acc: 0.9306 - val_loss: 0.6088 - val_acc: 0.7588
#
# Epoch 00092: val_acc did not improve from 0.79750
# Epoch 93/100
#  - 56s - loss: 0.1609 - acc: 0.9400 - val_loss: 0.6060 - val_acc: 0.7400
#
# Epoch 00093: val_acc did not improve from 0.79750
# Epoch 94/100
#  - 56s - loss: 0.1616 - acc: 0.9394 - val_loss: 0.6059 - val_acc: 0.7556
#
# Epoch 00094: val_acc did not improve from 0.79750
# Epoch 95/100
#  - 56s - loss: 0.1617 - acc: 0.9359 - val_loss: 0.6484 - val_acc: 0.7481
#
# Epoch 00095: val_acc did not improve from 0.79750
# Epoch 96/100
#  - 56s - loss: 0.1613 - acc: 0.9387 - val_loss: 0.6625 - val_acc: 0.7275
#
# Epoch 00096: val_acc did not improve from 0.79750
# Epoch 97/100
#  - 57s - loss: 0.1748 - acc: 0.9331 - val_loss: 0.6398 - val_acc: 0.7362
#
# Epoch 00097: val_acc did not improve from 0.79750
# Epoch 98/100
#  - 56s - loss: 0.1805 - acc: 0.9284 - val_loss: 0.6521 - val_acc: 0.7344
#
# Epoch 00098: val_acc did not improve from 0.79750
# Epoch 99/100
#  - 56s - loss: 0.1611 - acc: 0.9406 - val_loss: 0.6036 - val_acc: 0.7581
#
# Epoch 00099: val_acc did not improve from 0.79750
# Epoch 100/100
#  - 56s - loss: 0.1617 - acc: 0.9403 - val_loss: 0.6191 - val_acc: 0.7450
#
# Epoch 00100: val_acc did not improve from 0.79750

# %%
test_path = "../input/test/"


def chunker(seq, size=32):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))


from tqdm import tqdm

submission = pd.read_csv('../input/sample_submission.csv')

predictions = []

for batch in tqdm(chunker(submission.img_pair.values)):
    X1 = [x.split("-")[0] for x in batch]
    X1 = np.array([read_img(test_path + x) for x in X1])

    X2 = [x.split("-")[1] for x in batch]
    X2 = np.array([read_img(test_path + x) for x in X2])

    pred = model.predict([X1, X2]).ravel().tolist()
    predictions += pred

submission['is_related'] = predictions

submission.to_csv("vgg_face.csv", index=False)
# Out:
# 166it [00:52,  2.53it/s]
